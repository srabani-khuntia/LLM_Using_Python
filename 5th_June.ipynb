# %% [markdown]
# <a href="https://colab.research.google.com/github/srabani-khuntia/LLM_Using_Python/blob/main/5th_June.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torchvision.transforms as transforms
import torchvision.datasets as datasets

from torch.utils.data import DataLoader

import matplotlib.pyplot as plt
import numpy as np
import torchvision.utils as vutils

# %%
#Define transformations for the dataset

transform = transforms.Compose([
    transforms.Resize(64), #Resize images to 64x64
    transforms.CenterCrop(64), #Crop the central part of the image
    transforms.ToTensor(), #Convert images to tensors
    transforms.Normalize(mean=[0.5,0.5,0.5], std=[0.5,0.5,0.5]) #Normalise the images
])

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive"
# Out:
# '1st Yrs Announcement Plans.gsheet'
#  archive.zip
#  certificate.pdf
# 'Colab Notebooks'
#  ddd_v2.keras
#  file1.txt
# 'id card.jpeg'
#  lfw_funneled
# 'Meeting notes.gdoc'
# 'Photo from Srabani Khuntia'
# 'Report (1).gdoc'
# 'Report (2).gdoc'
#  Report.gdoc
# 'Report - Pie chart 1.gsheet'
#  SAVE_20250929_175510.jpg
# 'Scorecard 2.pdf'
# 'SWITCH Core Team Recruitment 2026 (Responses) (1).gsheet'
#  VID-20191022-WA0001.mp4
# 'WhatsApp Image 2025-01-10 at 11.12.00 PM.jpeg'
# 'WhatsApp Image 2025-01-10 at 11.13.55 PM.jpeg'

# %%
# !cp -r "/content/drive/MyDrive/lfw_funneled" .
# Out:
# ^C

# %%
# !ls
# Out:
# drive  lfw_funneled  sample_data

# %%
# !mkdir -p data
# !mv lfw_funneled data/

# %%
# !find data -maxdepth 2 | head -20
# Out:
# data
# data/lfw_funneled
# data/lfw_funneled/George_W_Bush
# data/lfw_funneled/Amelie_Mauresmo
# data/lfw_funneled/Albert_Costa
# data/lfw_funneled/Bill_Simon

# %%
dataset = datasets.ImageFolder(
    root='./data/lfw_funneled',
    transform=transform
)


dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

# %%
#Function to unnormalize and display images
def imshow(img):
  img = img/2 + 0.5
  npimg = img.numpy()
  plt.imshow(np.transpose(npimg, (1,2,0)))
  plt.show()

# %%
#Get a batch of images
dataiter = iter(dataloader)
images, _ = next(dataiter)

#Show the images
imshow(vutils.make_grid(images))
