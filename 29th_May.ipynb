# %% [markdown]
# <a href="https://colab.research.google.com/github/srabani-khuntia/LLM_Using_Python/blob/main/29th_May.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
m = 2
c = 3
np.random.seed(42) #universal no. as represents life history
X = np.random.rand(500)
y = m*X + c + np.random.randn(500)

# %%
plt.plot(X,y,'bo')
plt.show()

# %%
split_ratio = 0.8
split_index = int(split_ratio*len(X))

X_train,X_test = X[:split_index],X[split_index:]
y_train,y_test = y[:split_index],y[split_index:]

# %%
weights = np.random.randn(2) #2 weights: slope & intercept

learning_rate = 0.01
epochs = 1000

# %%
for epoch in range(epochs):
  y_pred = weights[0] + weights[1]*X_train
  error = y_pred - y_train
  gradient_intercept = np.mean(error)
  gradient_slope = np.mean(error*X_train)
  weights[0] -= learning_rate*gradient_intercept
  weights[1] -= learning_rate*gradient_slope

# %%
# Evaluate on the training set
y_pred_test = weights[0] + weights[1]*X_test
mse = np.mean((y_pred_test - y_test)**2)

# %%
plt.scatter(X, y, label = 'Data Points')
plt.plot(X_test, y_pred_test, color = 'red', label = 'Linear Regression Line')

# Set plot labels and legend
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()

# %%
import torch
torch.__version__
# Out:
# '2.11.0+cpu'

# %%
# create a simple tensor

x = torch.tensor([[1,2,3], [4,5,6]])
y = torch.tensor([[7,8,9], [10,11,12]])

sum = x+y
print(sum)
print(sum.device)
# Out:
# tensor([[ 8, 10, 12],
#         [14, 16, 18]])
# cpu

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(42)
X = np.random.rand(100, 1) * 10
y = 2*X + 3 + np.random.randn(100, 1)

# %%
# Creating the scatter plot
plt.scatter(X, y, label = 'Data Points')

# Adding Labels and title
plt.xlabel('X')
plt.ylabel('y')
plt.title('Scatter Plot of X and y')

# Adding a legend
plt.legend()

# Displaying the plot
plt.show()

# %%
X_tensor = torch.tensor(X, dtype = torch.float32)
y_tensor = torch.tensor(y, dtype = torch.float32)

def linear_regression(input_size, output_size):
  return nn.Linear(input_size, output_size)

input_size = 1
output_size = 1
model = linear_regression(input_size, output_size)

# %%
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr = 0.01)

# %%
num_epochs = 1000
for epoch in range(num_epochs):
  y_pred = model(X_tensor)
  loss = criterion(y_pred, y_tensor)
  optimizer.zero_grad()
  loss.backward()
  optimizer.step()

  if (epoch+1) % 100 == 0:
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')
# Out:
# Epoch [100/1000], Loss: 1.2068
# Epoch [200/1000], Loss: 0.9382
# Epoch [300/1000], Loss: 0.8498
# Epoch [400/1000], Loss: 0.8208
# Epoch [500/1000], Loss: 0.8113
# Epoch [600/1000], Loss: 0.8081
# Epoch [700/1000], Loss: 0.8071
# Epoch [800/1000], Loss: 0.8068
# Epoch [900/1000], Loss: 0.8066
# Epoch [1000/1000], Loss: 0.8066

# %%
# Parameters
num_points = 200
x_range = np.linspace(0,10, num_points)
noise = np.random.normal(0, 0.3, num_points)

# Generate zigza points
y = np.sin(x_range)+noise

# %%
# Creating the scatter plot
plt.scatter(x_range, y, label = 'Data Points')

# Adding Labels and title
plt.xlabel('x_range')
plt.ylabel('y')
plt.title('Scatter Plot of x_range and y')

# Adding a legend
plt.legend()

# Displaying the plot
plt.show()

# %%
# Define a simple neura network using a sequential module

model = nn.Sequential(
    nn.Linear(1,50), #Input Layer: 1 input feature, 50 neurons
    nn.Tanh(), #Activation Function
    nn.Linear(50,1) #Output Layer: 50 neurons, 1 output feature
)

# %%
# Training Loop

num_epochs = 10000

for epoch in range(num_epochs):
  #Forward pass
  #print(x_data.unsqueeze(1).shape)

  y_pred = model(torch.tensor(x_range, dtype = torch.float32).unsqueeze(1))
  loss = criterion(y_pred, torch.tensor(y, dtype = torch.float32).unsqueeze(1))

  #Backpropagation and optimisation
  optimizer.zero_grad()
  loss.backward()
  optimizer.step()

  if (epoch+1) % 100 == 0:
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')
# Out:
# Epoch [100/10000], Loss: 0.7020
# Epoch [200/10000], Loss: 0.7020
# Epoch [300/10000], Loss: 0.7020
# Epoch [400/10000], Loss: 0.7020
# Epoch [500/10000], Loss: 0.7020
# Epoch [600/10000], Loss: 0.7020
# Epoch [700/10000], Loss: 0.7020
# Epoch [800/10000], Loss: 0.7020
# Epoch [900/10000], Loss: 0.7020
# Epoch [1000/10000], Loss: 0.7020
# Epoch [1100/10000], Loss: 0.7020
# Epoch [1200/10000], Loss: 0.7020
# Epoch [1300/10000], Loss: 0.7020
# Epoch [1400/10000], Loss: 0.7020
# Epoch [1500/10000], Loss: 0.7020
# Epoch [1600/10000], Loss: 0.7020
# Epoch [1700/10000], Loss: 0.7020
# Epoch [1800/10000], Loss: 0.7020
# Epoch [1900/10000], Loss: 0.7020
# Epoch [2000/10000], Loss: 0.7020
# Epoch [2100/10000], Loss: 0.7020
# Epoch [2200/10000], Loss: 0.7020
# Epoch [2300/10000], Loss: 0.7020
# Epoch [2400/10000], Loss: 0.7020
# Epoch [2500/10000], Loss: 0.7020
# Epoch [2600/10000], Loss: 0.7020
# Epoch [2700/10000], Loss: 0.7020
# Epoch [2800/10000], Loss: 0.7020
# ...

# %%
# Parameters
num_points = 200
x_range = np.linspace(0,10, num_points)
noise = np.random.normal(0, 0.3, num_points)

# Generate zigza points
y = np.sin(x_range)+noise


# Creating the scatter plot
plt.scatter(x_range, y, label = 'Data Points')
plt.plot(x_range, y, color = 'red', label = 'Learned curve')

# Adding Labels and title
plt.xlabel('x_range')
plt.ylabel('y')
plt.title('Zigzag Data and Learned Curve')

# Adding a legend
plt.legend()

# Displaying the plot
plt.show()
